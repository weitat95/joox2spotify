# %%
# coding: utf8

from bs4 import BeautifulSoup

#Download Joox Playlist in html
with open("./joox_raw.html") as fp:
    soup = BeautifulSoup(fp,'lxml')

# %%
list_ = []
for b in soup.find_all('b'):
#     print(b).encode('utf-8')
    print(b.get_text())
    list_.append(b.get_text())
# soup.findAll("div", {"class": "SongDesc"})[0]
# Out:
# Diamond Heart (Syn Cole Remix)
# Yi Qian Wan Ci De Lei Shui
# Don't Give Up On Me (From "Five Feet Apart")
# Don't Give Up On Me
# Yu Ji
# Sparkle (Movie ver.)
# Dream Lantern
# Solo (feat. Demi Lovato)
# 成全
# Gei Wo Yi Ge Li You Wang Ji
# Que Kou (Dian Ying "Deng Yi Ge Ren Ka Fei" Zhu Ti Qu)
# At Least I've Got You
# 致姗姗来迟的你
# Guan Zhong
# Ren Zhen De Xue
# Rang Wo Liu Zai Ni Shen Bian
# Wandering Poet
# Gai Wang De Ri Zi - Han Ju " Yun Hua De Yue Guang " Pian Wei Qu
# After Saying Goodbye
# Shui San Jiu San
# Shui Huang
# Shei (Live Version)
# 贝加尔湖畔
# Walking in the cold
# Tiao Wu De Fan Gu
# Dian Qi Jiao Jian Ai
# Lose Myself
# 過得去 (<我租了一個情人>插曲)
# Still Missing
# Lian Ming Dai Xing
# The Light Runner
# The man
# 醉赤壁
# 野子
# Wrong Man
# Stranger
# Mo Sheng Ren
# Pei Ni - Dian Ying " Ling Bo Te Fan Nao " Zhu Ti Qu
# Sweetness In The Rain
# Youth Lies Within
# Tough
# Under The Cloud
# Mo Gui Zhong De Tian Shi
# 鱼仔
# LET'S NOT FALL IN LOVE
# Zenzenzense
# Wang Le Wo
# ...

# %%
print(list_[:-3]) # remove last 3
# Out:
# [u'Diamond Heart (Syn Cole Remix)', u'Yi Qian Wan Ci De Lei Shui', u'Don\'t Give Up On Me (From "Five Feet Apart")', u"Don't Give Up On Me", u'Yu Ji', u'Sparkle (Movie ver.)', u'Dream Lantern', u'Solo (feat. Demi Lovato)', u'\u6210\u5168', u'Gei Wo Yi Ge Li You Wang Ji', u'Que Kou (Dian Ying "Deng Yi Ge Ren Ka Fei" Zhu Ti Qu)', u"At Least I've Got You", u'\u81f4\u59d7\u59d7\u6765\u8fdf\u7684\u4f60', u'Guan Zhong', u'Ren Zhen De Xue', u'Rang Wo Liu Zai Ni Shen Bian', u'Wandering Poet', u'Gai Wang De Ri Zi - Han Ju " Yun Hua De Yue Guang " Pian Wei Qu', u'After Saying Goodbye', u'Shui San Jiu San', u'Shui Huang', u'Shei (Live Version)', u'\u8d1d\u52a0\u5c14\u6e56\u7554', u'Walking in the cold', u'Tiao Wu De Fan Gu', u'Dian Qi Jiao Jian Ai', u'Lose Myself', u'\u904e\u5f97\u53bb (<\u6211\u79df\u4e86\u4e00\u500b\u60c5\u4eba>\u63d2\u66f2)', u'Still Missing', u'Lian Ming Dai Xing', u'The Light Runner', u'The man', u'\u9189\u8d64\u58c1', u'\u91ce\u5b50', u'Wrong Man', u'Stranger', u'Mo Sheng
# ...
